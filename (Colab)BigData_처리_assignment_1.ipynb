# %% [markdown]
# # Given Code from Professor

# %%
#Upload a file from your hard disk
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d92d87a7-d8c6-4caf-9eeb-46b3d4868fb9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d92d87a7-d8c6-4caf-9eeb-46b3d4868fb9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Health.xlsx to Health.xlsx

# %%
#Applied to use Korean fonts
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# The data file (Health.xlsx) was created by collecting data that is freely available from the Health Insurance Corporation (https://nhiss.nhis.or.kr/bd/ay/bdaya001iv.do).
# Gender is assigned numerically as male 1 female 2

# %%
import io
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import numpy as np

plt.rc('font', family='NanumBarunGothic')

data = pd.read_excel('Health.xlsx') #Read uploaded file
X = data.iloc[:, [18, 22]].values   # Cut by selecting a column section in the Excel file, the column always starts from 0
#pd.read_csv('파일명', encoding='cp949') if we read csv file include "hangul"
data.head()
# Out:
#    NO     연령  성별  Q1  Q2  ...  확장기 혈압  확장기 5년 전  신장〔㎝〕  체중〔㎏〕  ５년 전 체중〔㎏〕
# 0      1  41   1   3   1  ...      91        59  169.4   57.0        50.1
# 1      2  30   1   2   1  ...      76        92  164.5   76.6        67.7
# 2      3  44   2   2   1  ...      79        37  155.6   56.5        31.2
# 3      4  54   1   2   2  ...      62        62  163.7   53.5        58.1
# 4      5  57   1   2   2  ...      89        70  156.1   64.1        38.3
#
# [5 rows x 23 columns]

# %%
data.describe()
# Out:
#            NO            연령         성별  ...       신장〔㎝〕      체중〔㎏〕  ５년 전 체중〔㎏〕
# count  60.000000  60.000000  60.000000  ...   60.000000  60.000000   60.000000
# mean   30.500000  44.750000   1.500000  ...  161.435000  59.965000   56.406667
# std    17.464249   8.365841   0.504219  ...    8.357962  11.445313   14.985098
# min     1.000000  30.000000   1.000000  ...  141.500000  41.800000   31.200000
# 25%    15.750000  38.000000   1.000000  ...  155.575000  52.625000   45.825000
# 50%    30.500000  44.500000   1.500000  ...  161.400000  56.900000   53.900000
# 75%    45.250000  52.000000   2.000000  ...  168.475000  66.625000   64.825000
# max    60.000000  59.000000   2.000000  ...  177.500000  95.000000   96.100000
#
# [8 rows x 23 columns]

# %%
data[['연령','심근경색','수축기 혈압']]
# Out:
#     연령  심근경색  수축기 혈압
# 0   41     2     137
# 1   30     1     126
# 2   44     1     165
# 3   54     1     102
# 4   57     1     136
# 5   48     2     109
# 6   53     2     131
# 7   35     1     116
# 8   38     1     105
# 9   46     1     122
# 10  46     2     147
# 11  35     1     109
# 12  54     1     166
# 13  58     1     121
# 14  52     2     169
# 15  35     1     125
# 16  42     1      92
# 17  57     1     129
# 18  43     2     111
# 19  52     1     125
# 20  48     1     131
# 21  56     1     119
# 22  51     2      93
# 23  35     1     104
# 24  50     2     159
# 25  37     1     110
# 26  34     2     118
# 27  54     2     130
# 28  40     2     122
# 29  37     1      97
# 30  46     2     116
# 31  54     1     112
# 32  42     1     121
# 33  31     1     127
# 34  33     2     172
# 35  47     2      93
# 36  52     1     111
# 37  39     2     138
# 38  43     1     100
# 39  55     1     122
# 40  47     1     124
# 41  38     1     107
# ...

# %%
plt.figure(figsize=(12, 5))
sns.scatterplot(x='연령', y='수축기 혈압', data=data, hue='성별')
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# # problem 1~3

# %% [markdown]
# #**Problem 1. Display the distribution of weight and age as shown in the graph above. If Hangul is not displayed properly, after installing the font, run Runtime->Restart in the Google Colab menu and run it except the codes for installing the font.**

# %%
plt.figure(figsize=(12, 5))
sns.scatterplot(x='연령', y='체중〔㎏〕', data=data, hue='성별')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# ## **Problem 2. Using the graph obtained in Problem 1, show the results of applying the silhouette value and k-mean cluster**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm 
import numpy as np
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples,silhouette_score
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 내가 짜본 코드드

# %%
import sklearn.cluster as cluster
import sklearn.metrics as metrics

# %%
age_weight = data[['연령', '체중〔㎏〕']]
age_weight.head()
# Out:
#    연령  체중〔㎏〕
# 0  41   57.0
# 1  30   76.6
# 2  44   56.5
# 3  54   53.5
# 4  57   64.1

# %%
for i in range(2,60):
  labels = cluster.KMeans(n_clusters = i, init = "k-means++", random_state = 200).fit(age_weight).labels_
  print("number of clusters : ",i)
  print("silhouette score : ",metrics.silhouette_score(age_weight,labels,metric="euclidean",sample_size=1000, random_state=200))
# Out:
# number of clusters :  2
# silhouette score :  0.4638488022055885
# number of clusters :  3
# silhouette score :  0.41196721530752545
# number of clusters :  4
# silhouette score :  0.3983188284822591
# number of clusters :  5
# silhouette score :  0.37482266763626165
# number of clusters :  6
# silhouette score :  0.36772723405721586
# number of clusters :  7
# silhouette score :  0.3281247933765696
# number of clusters :  8
# silhouette score :  0.33513360676881093
# number of clusters :  9
# silhouette score :  0.3501928198812474
# number of clusters :  10
# silhouette score :  0.3248289868594944
# number of clusters :  11
# silhouette score :  0.36959780490839494
# number of clusters :  12
# silhouette score :  0.36428955777426075
# number of clusters :  13
# silhouette score :  0.38154887809106136
# number of clusters :  14
# silhouette score :  0.3813758655365051
# number of clusters :  15
# silhouette score :  0.3978334090894208
# number of clusters :  16
# ...

# %% [markdown]
# # **Conclusion!!!**
# # since Silhouette score is highest at cluster number = 2 , clustering is well done when it comes to 2 clusters

# %% [markdown]
# # 교수님 수업 코드 참고
#
# # *참고 site
#
# https://steadiness-193.tistory.com/284
#
# # 코드가 너무 길어지므로 위에서 cluster 값을 다 뽑은 관계로 아래 코드에서는 cluster 값이 2~10 개까지만 뽑는것으로 한다.

# %%
best_cluster = -1
best_silhouette_score = -1

enum_list = []
for i in range(1,11):
  enum_list.append(i+1)
age_weight = data[['연령', '체중〔㎏〕']]
plt.scatter(age_weight['연령'],age_weight['체중〔㎏〕'])

for i,k in enumerate(enum_list):
    fig, ax = plt.subplots(1,2,figsize = (15,5))
    
    #Run the kmenas algorithm
    km = KMeans(n_clusters = k)
    y_predict = km.fit_predict(age_weight)
    centroids = km.cluster_centers_
    
    silhouette_vals = silhouette_samples(age_weight,y_predict)
    #calculate silhouette score
    score = silhouette_score(age_weight, km.labels_, metric = 'euclidean')
    #print the score
    print("For n_clusters = ", k,
         "the average silhouette_score is :", score)
    if score > best_silhouette_score:
          best_cluster = k
          best_silhouette_score = score
    print("best cluster number : ", best_cluster, "best_score : ", best_silhouette_score)

    y_ticks = []
    y_lower = y_upper = 0
        

    for i, cluster in enumerate(np.unique(y_predict)):
        cluster_silhouette_vals = silhouette_vals[y_predict == cluster]
        cluster_silhouette_vals.sort()
        y_upper += len(cluster_silhouette_vals)

        ax[0].barh(range(y_lower,y_upper),
                  cluster_silhouette_vals,height = 1)
        ax[0].text(-0.03,(y_lower+y_upper)/2,str(i+1))
        y_lower +=len(cluster_silhouette_vals)

        # get the average silhouette score
        avg_score = np.mean(silhouette_vals)
        ax[0].axvline(avg_score,linestyle = '--', linewidth = 2, color = 'green')
        ax[0].set_yticks([])
        ax[0].set_xlim([-0.1,1])
        ax[0].set_xlabel('Silhouette coefficient values')
        ax[0].set_ylabel('Cluster labels')
        ax[0].set_title('Silhouette plot for the various clusters')
    ax[1].scatter(age_weight['연령'],age_weight['체중〔㎏〕'], c = y_predict)
    ax[1].scatter(centroids[:,0],centroids[:,1],marker = '8', c = 'r', s = 250, label = 'Centroids');
    for i,c in enumerate(centroids):
        ax[1].scatter(c[0],c[1],marker = '$%d$' % i, alpha = 1, s = 50, edgecolor = 'k')

    ax[1].set_xlabel('Eurption time in mins')
    ax[1].set_ylabel('Waiting time to next eruption')
    ax[1].set_title('Visualizatino fo clustered data', y = 1.02)
    plt.suptitle(("silhouette analysis for KMEANs clustering on sample data" "with n_clusters = %d" %k),
                     fontsize = 13, fontweight = 'semibold')
plt.show()
# Out:
# For n_clusters =  2 the average silhouette_score is : 0.46384880220558844
# best cluster number :  2 best_score :  0.46384880220558844
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# For n_clusters =  3 the average silhouette_score is : 0.40384804739442515
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  4 the average silhouette_score is : 0.39970290027500704
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  5 the average silhouette_score is : 0.37482266763626176
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  6 the average silhouette_score is : 0.3677272340572158
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  7 the average silhouette_score is : 0.34041783466134473
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  8 the average silhouette_score is : 0.3598983078663848
# ...

# %% [markdown]
# **the more silhouette score close to 1, more well done the clustering is when the clustered number is 2!!!!!**

# %%
kmeans = KMeans(n_clusters= 2, init="k-means++")
kmeans = kmeans.fit(age_weight)

age_weight['Clusters'] = kmeans.labels_

plt.figure(figsize=(12, 5))
sns.scatterplot(x='연령', y='체중〔㎏〕', data=age_weight, hue='Clusters')

# %% [markdown]
# ## **Problem 3. When comparing men and women, plot the graph showing which gender has higher blood pressure**

# %%
plt.figure(figsize=(12, 5))
sns.scatterplot(x='수축기 혈압', y='확장기 혈압', data=data, hue='성별')

# %% [markdown]
# ## **일단 성별에 대해서 혈압을 체크 해보자**

# %%
data.groupby(['성별'], as_index = False).mean()
# Out:
#    성별      NO            연령   Q1  ...   확장기 5년 전   신장〔㎝〕      체중〔㎏〕  ５년 전 체중〔㎏〕
# 0   1  28.266667  44.266667  2.3  ...  73.100000  167.54  67.463333   58.123333
# 1   2  32.733333  45.233333  2.2  ...  67.033333  155.33  52.466667   54.690000
#
# [2 rows x 23 columns]

# %%
data.groupby('성별')['수축기 혈압'].agg(**{'수축기 혈압':'mean'}).reset_index()
# Out:
#    성별      수축기 혈압
# 0   1  125.200000
# 1   2  119.333333

# %%
data.groupby('성별')['확장기 혈압'].agg(**{'확장기 혈압':'mean'}).reset_index()
# Out:
#    성별  확장기 혈압
# 0   1    73.6
# 1   2    66.2

# %%
data.groupby('성별')['수축기 5년 전'].agg(**{'수축기 5년 전':'mean'}).reset_index()
# Out:
#    성별    수축기 5년 전
# 0   1  122.966667
# 1   2  117.100000

# %%
data.groupby('성별')['확장기 5년 전'].agg(**{'확장기 5년 전':'mean'}).reset_index()
# Out:
#    성별   확장기 5년 전
# 0   1  73.100000
# 1   2  67.033333

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x = '성별', y = '수축기 혈압', data = data )

# %%
plt.figure(figsize = (12,5))
sns.boxplot(x = '성별', y = '확장기 혈압', data = data )

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x = '성별', y = '수축기 5년 전', data = data )

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x = '성별', y = '확장기 5년 전', data = data )

# %%
data['수축기_혈압_avg'] = (data['수축기 혈압']+data['수축기 5년 전'])/2
data['확장기_혈압_avg'] = (data['확장기 혈압']+data['확장기 5년 전'])/2
data.head()
# Out:
#    NO     연령  성별  Q1  Q2  ...  신장〔㎝〕  체중〔㎏〕  ５년 전 체중〔㎏〕  수축기_혈압_avg  확장기_혈압_avg
# 0      1  41   1   3   1  ...  169.4   57.0        50.1       117.5        75.0
# 1      2  30   1   2   1  ...  164.5   76.6        67.7       144.5        84.0
# 2      3  44   2   2   1  ...  155.6   56.5        31.2       116.5        58.0
# 3      4  54   1   2   2  ...  163.7   53.5        58.1       107.5        62.0
# 4      5  57   1   2   2  ...  156.1   64.1        38.3       124.5        79.5
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x = '성별', y = '수축기_혈압_avg', data = data )

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x = '성별', y = '확장기_혈압_avg', data = data )

# %% [markdown]
# # 검색을을 통해서서 확인해 본 결과, 확장기 혈압 과 수축기 혈압의 평균 값을 통해서 혈압을 측정하기도 한다.

# %%
data['Avg(수축기,확장기)'] = (data['수축기 혈압']+data['확장기 혈압'])/2
data.head()
# Out:
#    NO     연령  성별  Q1  ...  ５년 전 체중〔㎏〕  수축기_혈압_avg  확장기_혈압_avg  Avg(수축기,확장기)
# 0      1  41   1   3  ...        50.1       117.5        75.0         114.0
# 1      2  30   1   2  ...        67.7       144.5        84.0         101.0
# 2      3  44   2   2  ...        31.2       116.5        58.0         122.0
# 3      4  54   1   2  ...        58.1       107.5        62.0          82.0
# 4      5  57   1   2  ...        38.3       124.5        79.5         112.5
#
# [5 rows x 26 columns]

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x = '성별', y = 'Avg(수축기,확장기)', data = data )

# %% [markdown]
# # **1번 성이 2 번성보다 혈압이 대체적으로 높다! **

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```
