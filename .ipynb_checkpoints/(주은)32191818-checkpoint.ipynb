# %%
#Upload a file from your hard disk
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-760b584f-cafc-4054-bd76-f6d8f4f74e2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-760b584f-cafc-4054-bd76-f6d8f4f74e2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Health.xlsx to Health (1).xlsx

# %%
#Applied to use Korean fonts
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# The data file (Health.xlsx) was created by collecting data that is freely available from the Health Insurance Corporation (https://nhiss.nhis.or.kr/bd/ay/bdaya001iv.do).
# Gender is assigned numerically as male 1 female 2

# %%
import io
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import numpy as np

plt.rc('font', family='NanumBarunGothic')

data = pd.read_excel('Health.xlsx') #Read uploaded file
X = data.iloc[:, [18, 22]].values   # Cut by selecting a column section in the Excel file, the column always starts from 0
#pd.read_csv('파일명', encoding='cp949') if we read csv file include "hangul"
data.head()
# Out:
#    NO     연령  성별  Q1  Q2  ...  확장기 혈압  확장기 5년 전  신장〔㎝〕  체중〔㎏〕  ５년 전 체중〔㎏〕
# 0      1  41   1   3   1  ...      91        59  169.4   57.0        50.1
# 1      2  30   1   2   1  ...      76        92  164.5   76.6        67.7
# 2      3  44   2   2   1  ...      79        37  155.6   56.5        31.2
# 3      4  54   1   2   2  ...      62        62  163.7   53.5        58.1
# 4      5  57   1   2   2  ...      89        70  156.1   64.1        38.3
#
# [5 rows x 23 columns]

# %%
data[['연령','심근경색','수축기 혈압']]
# Out:
#     연령  심근경색  수축기 혈압
# 0   41     2     137
# 1   30     1     126
# 2   44     1     165
# 3   54     1     102
# 4   57     1     136
# 5   48     2     109
# 6   53     2     131
# 7   35     1     116
# 8   38     1     105
# 9   46     1     122
# 10  46     2     147
# 11  35     1     109
# 12  54     1     166
# 13  58     1     121
# 14  52     2     169
# 15  35     1     125
# 16  42     1      92
# 17  57     1     129
# 18  43     2     111
# 19  52     1     125
# 20  48     1     131
# 21  56     1     119
# 22  51     2      93
# 23  35     1     104
# 24  50     2     159
# 25  37     1     110
# 26  34     2     118
# 27  54     2     130
# 28  40     2     122
# 29  37     1      97
# 30  46     2     116
# 31  54     1     112
# 32  42     1     121
# 33  31     1     127
# 34  33     2     172
# 35  47     2      93
# 36  52     1     111
# 37  39     2     138
# 38  43     1     100
# 39  55     1     122
# 40  47     1     124
# 41  38     1     107
# 42  30     1     112
# 43  54     2     125
# 44  38     1      94
# 45  35     2     137
# 46  35     1     116
# 47  59     2     135
# 48  39     1     103
# 49  42     1     111
# 50  48     1      89
# 51  59     1     127
# 52  52     1     119
# 53  59     1     130
# 54  39     2     107
# 55  45     1     101
# 56  46     1     146
# 57  36     2     113
# 58  40     2     149
# 59  40     2     153

# %%
plt.figure(figsize=(12, 5))
sns.scatterplot(x='연령', y='수축기 혈압', data=data, hue='성별')

# %% [markdown]
# Problem 1. Display the distribution of weight and age as shown in the graph above. If Hangul is not displayed properly, after installing the font, run Runtime->Restart in the Google Colab menu and run it except the codes for installing the font.

# %%
plt.figure(figsize=(12, 5))
sns.scatterplot(x='연령', y='체중〔㎏〕', data=data, hue='성별')

# %% [markdown]
# Problem 2. Using the graph obtained in Problem 1, show the results of applying the silhouette value and k-mean cluster

# %% [markdown]
# Sol1)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples,silhouette_score

best_cluster = -1
best_silhouette_score = -1

enum_list = []
for i in range(1,59):
  enum_list.append(i+1)
age_weight = data[['연령', '체중〔㎏〕']]

plt.scatter(age_weight['연령'],age_weight['체중〔㎏〕'])

for i,k in enumerate(enum_list):
    fig, ax = plt.subplots(1,2,figsize = (15,5))
    
    #Run the kmenas algorithm
    km = KMeans(n_clusters = k)
    y_predict = km.fit_predict(age_weight)
    centroids = km.cluster_centers_
    
    silhouette_vals = silhouette_samples(age_weight,y_predict)
    #calculate silhouette score
    score = silhouette_score(age_weight, km.labels_, metric = 'euclidean')
    #print the score
    print("For n_clusters = ", k,
         "the average silhouette_score is :", score)
    if score > best_silhouette_score:
          best_cluster = k
          best_silhouette_score = score
    print("best cluster number : ", best_cluster, "best_score : ", best_silhouette_score)

    y_ticks = []
    y_lower = y_upper = 0
        

    for i, cluster in enumerate(np.unique(y_predict)):
        cluster_silhouette_vals = silhouette_vals[y_predict == cluster]
        cluster_silhouette_vals.sort()
        y_upper += len(cluster_silhouette_vals)

        ax[0].barh(range(y_lower,y_upper),
                  cluster_silhouette_vals,height = 1);
        ax[0].text(-0.03,(y_lower+y_upper)/2,str(i+1))
        y_lower +=len(cluster_silhouette_vals)

        # get the average silhouette score
        avg_score = np.mean(silhouette_vals)
        ax[0].axvline(avg_score,linestyle = '--', linewidth = 2, color = 'green')
        ax[0].set_yticks([])
        ax[0].set_xlim([-0.1,1])
        ax[0].set_xlabel('Silhouette coefficient values')
        ax[0].set_ylabel('Cluster labels')
        ax[0].set_title('Silhouette plot for the various clusters')

    ax[1].scatter(age_weight['연령'],age_weight['체중〔㎏〕'], c = y_predict)
    ax[1].scatter(centroids[:,0],centroids[:,1],marker = '8', c = 'r', s = 250, label = 'Centroids')
    for i,c in enumerate(centroids):
        ax[1].scatter(c[0],c[1],marker = '$%d$' % i, alpha = 1, s = 50, edgecolor = 'k')

    ax[1].set_xlabel('Eruption time in mins')
    ax[1].set_ylabel('Waiting time to next eruption')
    ax[1].set_title('Visualizatino fo clustered data', y = 1.02)
    plt.suptitle(("silhouette analysis for KMEANs clustering on sample data" "with n_clusters = %d" %k),
                     fontsize = 13, fontweight = 'semibold')
plt.show()
# Out:
# For n_clusters =  2 the average silhouette_score is : 0.46384880220558844
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  3 the average silhouette_score is : 0.41196721530752545
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  4 the average silhouette_score is : 0.4032557333573511
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  5 the average silhouette_score is : 0.37482266763626176
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  6 the average silhouette_score is : 0.3661562262975812
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  7 the average silhouette_score is : 0.36414870077307887
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  8 the average silhouette_score is : 0.35482705594007713
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  9 the average silhouette_score is : 0.3627524274847075
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  10 the average silhouette_score is : 0.3662961690462295
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  11 the average silhouette_score is : 0.3455742009544981
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  12 the average silhouette_score is : 0.38318123727157033
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  13 the average silhouette_score is : 0.35601138081693967
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  14 the average silhouette_score is : 0.3514175998712773
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  15 the average silhouette_score is : 0.374303086163286
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  16 the average silhouette_score is : 0.37341535806452403
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  17 the average silhouette_score is : 0.36661296004090005
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  18 the average silhouette_score is : 0.3651727869219038
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  19 the average silhouette_score is : 0.3703131423697678
# best cluster number :  2 best_score :  0.46384880220558844
# For n_clusters =  20 the average silhouette_score is : 0.3691339525482201
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  21 the average silhouette_score is : 0.38155201217910756
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  22 the average silhouette_score is : 0.3686508027347955
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  23 the average silhouette_score is : 0.3856186213551719
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  24 the average silhouette_score is : 0.3712990438058174
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  25 the average silhouette_score is : 0.36106582610787724
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  26 the average silhouette_score is : 0.37369115574157746
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  27 the average silhouette_score is : 0.3648994779625484
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  28 the average silhouette_score is : 0.37390614744779077
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  29 the average silhouette_score is : 0.3552883713685438
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  30 the average silhouette_score is : 0.3491388083997619
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  31 the average silhouette_score is : 0.3294258708331345
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  32 the average silhouette_score is : 0.34912248635572335
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  33 the average silhouette_score is : 0.3421576280111063
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  34 the average silhouette_score is : 0.34085041970894675
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  35 the average silhouette_score is : 0.30484235342885985
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  36 the average silhouette_score is : 0.3358439341259935
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  37 the average silhouette_score is : 0.32022306394793504
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  38 the average silhouette_score is : 0.31192475229408917
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  39 the average silhouette_score is : 0.29414489526866344
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  40 the average silhouette_score is : 0.2777426484069524
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  41 the average silhouette_score is : 0.2827302813977663
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  42 the average silhouette_score is : 0.26404571607610755
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  43 the average silhouette_score is : 0.24927759199434482
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  44 the average silhouette_score is : 0.26249155749858577
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  45 the average silhouette_score is : 0.22595529222200278
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  46 the average silhouette_score is : 0.2350342446898518
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  47 the average silhouette_score is : 0.21414251476396481
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  48 the average silhouette_score is : 0.19079417727733455
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  49 the average silhouette_score is : 0.19506817080863675
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  50 the average silhouette_score is : 0.18240041673698096
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  51 the average silhouette_score is : 0.1581812313133203
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  52 the average silhouette_score is : 0.14270082421181793
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  53 the average silhouette_score is : 0.12658242199048692
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  54 the average silhouette_score is : 0.10649450044943656
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  55 the average silhouette_score is : 0.09602954749947977
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  56 the average silhouette_score is : 0.07840607312327501
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  57 the average silhouette_score is : 0.05691635728890881
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  58 the average silhouette_score is : 0.0364285392872956
# best cluster number :  2 best_score :  0.46384880220558844
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from ipykernel import kernelapp as app
# For n_clusters =  59 the average silhouette_score is : 0.023846991868721697
# best cluster number :  2 best_score :  0.46384880220558844

# %% [markdown]
# Sol2)

# %%
import sklearn.cluster as cluster
import sklearn.metrics as metrics

df_data = data[['연령','체중〔㎏〕']]
for i in range(3,60):
    labels=cluster.KMeans(n_clusters=i, init="k-means++", random_state=200).fit(data).labels_
    print("Silhouette score for k(clusters) = "+str(i)+" is "
    +str(metrics.silhouette_score(data,labels,metric="euclidean",sample_size=1000, random_state=200)))

# %%
kmeans = cluster.KMeans(n_clusters=3, init="k-means++")
kmeans = kmeans.fit(df_data)

df_data['Clusters'] = kmeans.labels_

plt.figure(figsize=(12, 5))
sns.scatterplot(x='연령', y='체중〔㎏〕', data=df_data, hue='Clusters')

# %% [markdown]
# Problem 3. When comparing men and women, plot the graph showing which gender has higher blood pressure

# %%
data['avg1'] = (data['수축기 혈압']+data['수축기 5년 전'])/2
data['avg2'] = (data['확장기 혈압']+data['확장기 5년 전'])/2

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x = '성별', y = 'avg1', data = data )

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x = '성별', y = 'avg2', data = data )
